# %% [markdown]
# # Scratch Notebook
# For necessary scribbles.

# %%
import pandas as pd

# %%
filename = './test_data/test_sdir/snapshot_times.txt'

# %%
names = [ 'snum', 'scale-factor', 'redshift', 'time[Gyr]', 'time_width[Myr]' ]

# %%
snapshot_times = pd.read_csv( filename, delim_whitespace=True, skiprows=3, index_col=0, names=names )
snapshot_times
# Out:
#       scale-factor   redshift  time[Gyr]  time_width[Myr]
# snum
# 0         0.010000  99.000000   0.017805          0.00000
# 1         0.050000  19.000000   0.199051        181.24639
# 2         0.062500  15.000000   0.278168         79.11648
# 3         0.064078  14.605911   0.288768         10.60047
# 4         0.065657  14.230769   0.299500         10.73151
# 5         0.067235  13.873240   0.310361         10.86104
# 6         0.068813  13.532110   0.321349         10.98891
# 7         0.070391  13.206278   0.332465         11.11538
# 8         0.071970  12.894737   0.343705         11.24029
# 9         0.073548  12.596566   0.355069         11.36391
# 10        0.075126  12.310925   0.366555         11.48606
# 11        0.076704  12.037037   0.378162         11.60699
# 12        0.078283  11.774194   0.389889         11.72653
# 13        0.079861  11.521739   0.401734         11.84495
# 14        0.081439  11.279070   0.413696         11.96204
# ...

# %%
snapshot_times['redshift ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6f6b5cb21c69> in <module>()
# ----> 1 snapshot_times['redshift ']
#
# /opt/apps/intel13/python/2.7.9/lib/python2.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1785             return self._getitem_multilevel(key)
#    1786         else:
# -> 1787             return self._getitem_column(key)
#    1788
#    1789     def _getitem_column(self, key):
#
# /opt/apps/intel13/python/2.7.9/lib/python2.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1792         # get column
#    1793         if self.columns.is_unique:
# -> 1794             return self._get_item_cache(key)
#    1795
#    1796         # duplicate columns & possible reduce dimensionaility
#
# /opt/apps/intel13/python/2.7.9/lib/python2.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...
