# %% [markdown]
# # Scratch Notebook
# For necessary scribbles.

# %%
import pandas as pd

# %%
import galaxy_diver

# %%
filename = './test_data/test_sdir/snapshot_times.txt'
analysis_sdir = './test_data/test_analysis_dir/'
sdir = './test_data/test_sdir/'
sdir2 = './test_data/test_sdir2/'

# %%
times = pd.read_csv( './test_data/test_sdir2/output_times.txt', names=['scale-factor'] )

# %%
times.index.name = 'snum'

# %%
times['redshift'] = 1./times['scale-factor'] - 1.

# %%
times
# Out:
#       scale-factor   redshift
# snum
# 0         0.032258  29.999966
# 1         0.034483  27.999965
# 2         0.037037  26.000027
# 3         0.040000  24.000000
# 4         0.043478  21.999979
# 5         0.047619  20.000021
# 6         0.050000  19.000000
# 7         0.052632  17.999992
# 8         0.055556  16.999986
# 9         0.058824  16.000009
# 10        0.062500  15.000000
# 11        0.064935  14.399992
# 12        0.067568  13.799993
# 13        0.070422  13.200007
# 14        0.073529  12.600002
# 15        0.076923  11.999996
# 16        0.079365  11.599997
# 17        0.081967  11.200002
# 18        0.084746  10.799995
# 19        0.087719  10.400000
# 20        0.090909   9.999999
# 21        0.092593   9.799999
# 22        0.094340   9.600003
# 23        0.096154   9.400005
# 24        0.098039   9.200002
# 25        0.100000   9.000000
# 26        0.102041   8.799982
# 27        0.104167   8.599969
# 28        0.106383   8.399998
# 29        0.108696   8.199971
# ...

# %%
metafile_reader = galaxy_diver.read_metafile.MetafileReader( sdir )

# %%
metafile_reader.get_snapshot_times()

# %%
metafile_reader.snapshot_times['redshift'][ ahf_reader.mtree_halos[0].index ][599]
# Out:
# 0.0001593

# %%
metafile_reader.snapshot_times['redshift'][599]
# Out:
# 0.0001593

# %%
ahf_reader.mtree_halos[0].loc[250:200]
# Out:
#       redshift  ID  hostHalo  numSubStruct          Mvir     npart  \
# snum
# 250      1.187   0        -1           671  5.273310e+11  31632256
# 249      1.195   0        -1           662  5.225950e+11  31357477
# 248      1.203   0        -1           652  5.174010e+11  31060766
# 247      1.211   0        -1           686  5.121920e+11  30765988
# 246      1.218   0        -1           646  5.070800e+11  30465720
# 245      1.226   0        -1           648  5.023070e+11  30178291
# 244      1.234   0        -1           650  4.981300e+11  29895891
# 243      1.242   0        -1           660  4.929070e+11  29619299
# 242      1.250   0        -1           634  4.878400e+11  29320578
# 241      1.258   0        -1           641  4.817280e+11  28973445
# 240      1.266   0        -1           614  4.550660e+11  27548889
# 239      1.274   0        -1           603  4.639060e+11  27952398
# 238      1.283   0        -1           597  4.540490e+11  27366725
# ...
